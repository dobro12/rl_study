# %%
import torch
from torch import optim
import torch.nn as nn
import torch.nn.functional as F
import gym
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import random
import threading
import math

# %%
#hyper parameters
t_max = 10
gamma = 0.99
learning_rate = 0.001
beta = 0.1

seed = 0

np.random.seed(seed)
torch.manual_seed(seed)

# %%
class policy_net(nn.Module):
    def __init__(self, input_feature):
        super(policy_net,self).__init__()
        self.linear1 = nn.Linear(in_features = input_feature, out_features = 128)
        self.activation1 = nn.ReLU()
        self.linear2 = nn.Linear(in_features = 128, out_features = 1)
        self.linear3 = nn.Linear(in_features = 128, out_features = 1)
        self.mean_act = nn.Tanh()
        self.var_act = nn.Softplus()

        
    def forward(self,x):
        x = self.activation1(self.linear1(x))
        mean = self.mean_act(self.linear2(x)) * 2
        variance = self.var_act(self.linear3(x))
        return mean , variance
    
class value_net(nn.Module):
    def __init__(self, input_feature):
        super(value_net,self).__init__()
        self.linear1 = nn.Linear(in_features = input_feature, out_features = 128)
        self.activation1 = nn.ReLU()
        self.linear2 = nn.Linear(in_features = 128, out_features = 1)

        
    def forward(self,x):
        x = self.activation1(self.linear1(x))
        x = self.linear2(x)
        return x

# %%
def get_action(mean , variance):
    action = np.random.normal(mean.detach(), variance.detach(), 1).item()
    if(action < -2):
        return -2
    elif(action>2):
        return 2
    else:
        return action

# %%
#multihtread
p_net_shared = policy_net(3)
v_net_shared = value_net(3)
np.random.seed(seed)
torch.manual_seed(seed)

reward_plot = [0 for i in range(5000)]

def training(idx):
    t_max = 5
    gamma = 0.9
    learning_rate = 0.001
    beta = 0
    step = 0
    state = []
    
    env = gym.make('Pendulum-v0')

    global p_net_shared
    global v_net_shared
    p_optimizer = optim.Adam(p_net_shared.parameters(), lr=learning_rate)
    v_optimizer = optim.Adam(v_net_shared.parameters(), lr=learning_rate)
    global reward_plot
    
    for iteration in range(5000):
        done = False
        observation = env.reset()
        state = observation
        
        p_net = policy_net(3)
        v_net = value_net(3)
    
        p_net.zero_grad()
        v_net.zero_grad()
        
        t_update = 0
        #beta -= 0.0003
        #learning_rate -= 0.0009/2000
        if(iteration>2000):
            learning_rate = 0.0001
        if(beta<=0):
            beta = 0
        reward_stack = []
        prob_stack = []
        value_stack = []
        action_stack = []
        entropy = 0
        reward_sum = 0
        policy_loss_sum=0
        value_loss_sum = 0
        entropy_sum = 0
        for t in range(10000):

            step = step+1

            mean, variance= p_net(torch.Tensor(state))
            value = v_net(torch.Tensor(state))            
            
            action = get_action(mean,variance)
            
            next_state , reward, done, info = env.step([action])
            reward /= 16.2736044
            reward_sum += reward
            t_update += 1

            reward_stack.append(reward)
            value_stack.append(value)
            prob_stack.append((mean,variance))
            action_stack.append(action)
            
            entropy += -(torch.log(torch.clamp(2*math.pi*variance*variance , min = 1e-6)) + 1)/2

            if(t_update >= t_max or done):
                R = v_net(torch.Tensor(next_state))
                policy_loss = 0
                value_loss = 0
                

                for i in range(t_update):
                    R = R*gamma + reward_stack.pop()
                    value_temp = value_stack.pop()
                    mu , var = prob_stack.pop()
                    action_i = action_stack.pop()
                    
                    policy_loss += ( torch.log( torch.clamp(math.sqrt(2*math.pi)*var,min=1e-6) ) + (( (action_i - mu)/var )**2)/2 ) * (R-value_temp).detach()      
                    value_loss += (R-value_temp) * (R-value_temp)

                    
                entropy = -entropy * beta
                policy_loss = policy_loss + entropy 
                policy_loss = policy_loss / t_max
                value_loss = value_loss /t_max
                
                policy_loss.backward(retain_graph=True)
                value_loss.backward()
                policy_loss_sum += policy_loss.detach().numpy()
                value_loss_sum += value_loss.detach().numpy()
                update = 1
                for p_param , s_p_param , v_param , s_v_param in zip(p_net.parameters(), p_net_shared.parameters(), v_net.parameters(), v_net_shared.parameters()):
                    if(s_p_param.grad is not None and  s_p_param.grad.sum().detach().numpy() != 0):
                        update = 0
                        break
                    if(s_v_param.grad is not None and  s_v_param.grad.sum().detach().numpy() !=0):
                        update = 0
                        break
                    s_p_param._grad = p_param.grad.detach()
                    s_v_param._grad = v_param.grad.detach()
                    if((s_p_param != s_p_param).any()):
                        print("explode !!!! ")
                    
                if(update):
                    p_optimizer.step()
                    v_optimizer.step()
                    p_net_shared.zero_grad()
                    v_net_shared.zero_grad()
                
                p_net = policy_net(3)
                v_net = value_net(3)    

                p_net.load_state_dict(p_net_shared.state_dict())
                v_net.load_state_dict(v_net_shared.state_dict())
                R=0
                entropy = 0
                t_update = 0
            if(done):
                break

            #env.render()
            state = next_state[:]
        reward_plot[iteration] += reward_sum
        if(iteration%10 ==0):
            print(policy_loss_sum)
            print(value_loss_sum)
            print("training idx {} actor true_reward at iteration {} : {}".format(idx,iteration, reward_sum))
            print(step)
            beta = beta * 0.99
th1 = threading.Thread(target = training , args = (1,))
'''th2 = threading.Thread(target = training , args = (2,))
th3 = threading.Thread(target = training , args = (3,))
''''''th4 = threading.Thread(target = training , args = (4,))'''
th1.start()
'''th2.start()
th3.start()
''''''th4.start()'''

th1.join()
'''th2.join()
th3.join()
''''''th4.join()'''

print("finish")
# Out:
# /home/wooseoko/anaconda3/envs/spinningup/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# [-57.68265]
# [81.709755]
# training idx 1 actor true_reward at iteration 0 : -103.7629448515185
# 200
# [-1.9640435]
# [2.4404926]
# training idx 1 actor true_reward at iteration 10 : -92.8136086953789
# 2200
# [-0.19212511]
# [0.56823695]
# training idx 1 actor true_reward at iteration 20 : -91.86626862347654
# 4200
# [1.0569019]
# [0.90660715]
# training idx 1 actor true_reward at iteration 30 : -72.08527275953445
# 6200
# [-7.73626]
# [5.2223744]
# training idx 1 actor true_reward at iteration 40 : -81.58339315120534
# 8200
# [-2.8128226]
# [2.5466144]
# training idx 1 actor true_reward at iteration 50 : -68.42941203399705
# 10200
# [1.1136743]
# [4.342303]
# training idx 1 actor true_reward at iteration 60 : -69.38288547824557
# 12200
# [6.019872]
# [4.574699]
# training idx 1 actor true_reward at iteration 70 : -36.2704831939856
# 14200
# [-3.031286]
# [3.14572]
# training idx 1 actor true_reward at iteration 80 : -64.97865258946032
# 16200
# [-0.15530515]
# [0.6709666]
# training idx 1 actor true_reward at iteration 90 : -63.1481303253972
# 18200
# [1.7960316]
# [1.0582204]
# training idx 1 actor true_reward at iteration 100 : -23.85724692637409
# 20200
# [-3.699819]
# [0.88587916]
# training idx 1 actor true_reward at iteration 110 : -47.478165754210984
# 22200
# [-3.051005]
# [2.1392722]
# training idx 1 actor true_reward at iteration 120 : -66.62063687008913
# 24200
# [1.4551204]
# [2.5678391]
# training idx 1 actor true_reward at iteration 130 : -42.16644189033873
# 26200
# [0.42137936]
# [1.043057]
# training idx 1 actor true_reward at iteration 140 : -24.035904263155093
# 28200
# [-1.2975898]
# [0.94864935]
# training idx 1 actor true_reward at iteration 150 : -23.75279601063418
# 30200
# [-0.75311255]
# [0.15829276]
# training idx 1 actor true_reward at iteration 160 : -7.877830587170545
# 32200
# [-1.4376471]
# [0.6680039]
# training idx 1 actor true_reward at iteration 170 : -24.070079838902455
# 34200
# [-4.1181107]
# [3.4803526]
# training idx 1 actor true_reward at iteration 180 : -61.50274707146771
# 36200
# [-0.09096701]
# [0.3046945]
# training idx 1 actor true_reward at iteration 190 : -8.105205207658596
# 38200
# [-1.6695839]
# [0.6331785]
# training idx 1 actor true_reward at iteration 200 : -7.653752948791606
# 40200
# [1.0481435]
# [1.9222246]
# training idx 1 actor true_reward at iteration 210 : -63.8261281195532
# 42200
# [-1.7684685]
# [1.7751727]
# training idx 1 actor true_reward at iteration 220 : -42.00757536108313
# 44200
# [-1.6189402]
# [1.5776814]
# training idx 1 actor true_reward at iteration 230 : -15.304447296058422
# 46200
# [-2.5161536]
# [1.580257]
# training idx 1 actor true_reward at iteration 240 : -15.996909914745093
# 48200
# [-1.7915659]
# [0.525956]
# training idx 1 actor true_reward at iteration 250 : -15.565284725090287
# 50200
# [-0.27703702]
# [0.11828145]
# training idx 1 actor true_reward at iteration 260 : -7.913022112327889
# 52200
# [1.0204257]
# [0.30851686]
# training idx 1 actor true_reward at iteration 270 : -7.891377124292969
# 54200
# [-2.1778142]
# [1.0235748]
# training idx 1 actor true_reward at iteration 280 : -23.32536542253141
# 56200
# [-0.52579105]
# [0.58177197]
# training idx 1 actor true_reward at iteration 290 : -15.473273276207445
# 58200
# [0.6470353]
# [0.85855067]
# training idx 1 actor true_reward at iteration 300 : -24.109232652449894
# 60200
# [-0.46423578]
# [0.09756862]
# training idx 1 actor true_reward at iteration 310 : -7.854743467079483
# 62200
# [-0.50491965]
# [1.236384]
# training idx 1 actor true_reward at iteration 320 : -23.465370527987595
# 64200
# [0.008424]
# [0.00145445]
# training idx 1 actor true_reward at iteration 330 : -0.06623085980970284
# 66200
# [-3.7968192]
# [1.52573]
# training idx 1 actor true_reward at iteration 340 : -69.82065783765488
# 68200
# [-0.30439872]
# [0.08308781]
# training idx 1 actor true_reward at iteration 350 : -7.968547466294587
# 70200
# [-1.7434182]
# [1.5825723]
# training idx 1 actor true_reward at iteration 360 : -15.57427889918574
# 72200
# [-1.2493548]
# [2.6229563]
# training idx 1 actor true_reward at iteration 370 : -25.54562973161539
# 74200
# [-0.07481342]
# [0.08885712]
# training idx 1 actor true_reward at iteration 380 : -7.879524416550416
# 76200
# [-1.4749506]
# [1.9757566]
# training idx 1 actor true_reward at iteration 390 : -32.409931323819215
# 78200
# [-3.8559847]
# [5.581843]
# training idx 1 actor true_reward at iteration 400 : -67.25374903190341
# 80200
# [-1.0402759]
# [0.4415307]
# training idx 1 actor true_reward at iteration 410 : -7.8239521559759355
# 82200
# [-0.50996673]
# [0.34052345]
# training idx 1 actor true_reward at iteration 420 : -7.938460230525016
# 84200
# [-1.0154259]
# [0.30220792]
# training idx 1 actor true_reward at iteration 430 : -7.88032319868024
# 86200
# [-1.8228569]
# [2.4741616]
# training idx 1 actor true_reward at iteration 440 : -65.06914063976319
# 88200
# [-0.7367889]
# [0.4043549]
# training idx 1 actor true_reward at iteration 450 : -15.328865542197937
# 90200
# [-0.5220794]
# [0.34498155]
# training idx 1 actor true_reward at iteration 460 : -7.6476063449400336
# 92200
# [-1.8430339]
# [1.758088]
# training idx 1 actor true_reward at iteration 470 : -23.3421637751012
# 94200
# [1.0631028]
# [0.30155563]
# training idx 1 actor true_reward at iteration 480 : -7.936809883064477
# 96200
# [0.46897635]
# [1.5397642]
# training idx 1 actor true_reward at iteration 490 : -16.58536202054566
# 98200
# [-0.61985105]
# [0.10231531]
# training idx 1 actor true_reward at iteration 500 : -7.8317570187316505
# 100200
# [-0.89949137]
# [1.413894]
# training idx 1 actor true_reward at iteration 510 : -15.849016397226396
# 102200
# [-0.7174964]
# [0.68400687]
# training idx 1 actor true_reward at iteration 520 : -16.366171326848562
# 104200
# [-1.126196]
# [2.17715]
# training idx 1 actor true_reward at iteration 530 : -41.334426284959285
# 106200
# [-0.71918756]
# [2.2829964]
# training idx 1 actor true_reward at iteration 540 : -32.59353284433629
# 108200
# [-0.84518385]
# [0.734101]
# training idx 1 actor true_reward at iteration 550 : -7.388898632018367
# 110200
# [-0.5962477]
# [0.11487556]
# training idx 1 actor true_reward at iteration 560 : -7.85849915905992
# 112200
# [-1.1896104]
# [0.5499952]
# training idx 1 actor true_reward at iteration 570 : -16.048518246895128
# 114200
# [-0.559839]
# [0.12441989]
# training idx 1 actor true_reward at iteration 580 : -7.717541978939647
# 116200
# [0.01278167]
# [0.15044458]
# training idx 1 actor true_reward at iteration 590 : -8.116911154799267
# 118200
# [-1.851804]
# [1.3506902]
# training idx 1 actor true_reward at iteration 600 : -24.43022299153409
# 120200
# [-0.83361715]
# [1.6912391]
# training idx 1 actor true_reward at iteration 610 : -23.583697692473525
# 122200
# [0.32633394]
# [0.06004902]
# training idx 1 actor true_reward at iteration 620 : -7.771739433617681
# 124200
# [-1.0603632]
# [0.8867064]
# training idx 1 actor true_reward at iteration 630 : -15.600628866672666
# 126200
# [-0.12795852]
# [0.04353653]
# training idx 1 actor true_reward at iteration 640 : -8.019368263994693
# 128200
# [-0.06455932]
# [0.01563761]
# training idx 1 actor true_reward at iteration 650 : -0.02144484941603505
# 130200
# [-0.66196215]
# [0.21122098]
# training idx 1 actor true_reward at iteration 660 : -7.978394585388465
# 132200
# [-1.6221751]
# [1.6163741]
# training idx 1 actor true_reward at iteration 670 : -25.551701592753727
# 134200
# [-1.5750426]
# [1.7987558]
# training idx 1 actor true_reward at iteration 680 : -23.764335997911694
# 136200
# [-0.8348886]
# [0.33410197]
# training idx 1 actor true_reward at iteration 690 : -15.495654297658724
# 138200
# [-0.6233767]
# [0.17920357]
# training idx 1 actor true_reward at iteration 700 : -7.856088524284562
# 140200
# [-0.21213017]
# [1.2581333]
# training idx 1 actor true_reward at iteration 710 : -7.445953735083155
# 142200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-83b016418fdd> in <module>
#     144 ''''''th4.start()'''
#     145
# --> 146 th1.join()
#     147 '''th2.join()
#     148 th3.join()
#
# ~/anaconda3/envs/spinningup/lib/python3.6/threading.py in join(self, timeout)
#    1054
#    1055         if timeout is None:
# -> 1056             self._wait_for_tstate_lock()
#    1057         else:
#    1058             # the behavior of a negative timeout isn't documented, but
#
# ~/anaconda3/envs/spinningup/lib/python3.6/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1070         if lock is None:  # already determined that the C code is done
#    1071             assert self._is_stopped
# -> 1072         elif lock.acquire(block, timeout):
#    1073             lock.release()
#    1074             self._stop()
#
# KeyboardInterrupt:

# %%
reward_np = np.array(reward_plot[:700]) * 16.6
fig, axe = plt.subplots(1, figsize = (15,15))
axe.plot(list(range(len(reward_np))),reward_np, lw = 1, label = 'reward', color = 'blue')
axe.set_title('reward', fontsize = 30)
# Out:
# Text(0.5, 1.0, 'reward')
# [-2.5143094]
# [2.4305034]
# training idx 1 actor true_reward at iteration 730 : -75.00765199278888
# 146200
# [-2.0494428]
# [2.8701143]
# training idx 1 actor true_reward at iteration 740 : -43.22417571050885
# 148200
# [0.04186683]
# [0.03089561]
# training idx 1 actor true_reward at iteration 750 : -7.702519886772708
# 150200

# %%
#test
state = []
env = gym.make('Pendulum-v0')
done = False
reward_sum=0
observation = env.reset()
state = observation

for t in range(10000):
    env.render()
    
    mean, variance= p_net_shared(torch.Tensor(state))
    value = v_net_shared(torch.Tensor(state))

    action = get_action(mean,variance)
    
    obs , reward, done, info = env.step([action])
    
    
    reward_sum = reward_sum + reward
    state=obs
    if done:
        break
    
print("reward {}".format(reward_sum))
# Out:
# reward -131.97061242813115
# [-0.17759119]
# [0.14122337]
# training idx 1 actor true_reward at iteration 840 : -7.990068627312995
# 168200
# [0.25063616]
# [4.128906]
# training idx 1 actor true_reward at iteration 850 : -32.14083080182846
# 170200
# [-0.5325254]
# [2.4063332]
# training idx 1 actor true_reward at iteration 860 : -26.119063507079847
# 172200
# [-0.48913482]
# [0.6276605]
# training idx 1 actor true_reward at iteration 870 : -16.097952456363952
# 174200
# [-0.53250206]
# [0.3302607]
# training idx 1 actor true_reward at iteration 880 : -16.133945503938172
# 176200
# [-1.208782]
# [1.9310371]
# training idx 1 actor true_reward at iteration 890 : -24.292409509616036
# 178200
# [-0.74155957]
# [0.9935502]
# training idx 1 actor true_reward at iteration 900 : -23.884900777895655
# 180200
# [-0.17939553]
# [0.00516734]
# training idx 1 actor true_reward at iteration 910 : -0.11824852006206171
# 182200
# [-0.52635634]
# [0.32515544]
# training idx 1 actor true_reward at iteration 920 : -7.734147662230547
# 184200
# [-1.534134]
# [2.123571]
# training idx 1 actor true_reward at iteration 930 : -74.85348797839964
# 186200
# [-0.4599321]
# [0.15369368]
# training idx 1 actor true_reward at iteration 940 : -24.609807748078268
# 188200
# [-0.4350411]
# [0.47003812]
# training idx 1 actor true_reward at iteration 950 : -15.85193219004704
# 190200
# [-0.58015376]
# [0.22325127]
# training idx 1 actor true_reward at iteration 960 : -7.855964371363777
# 192200
# [-0.8680951]
# [2.0061557]
# training idx 1 actor true_reward at iteration 970 : -25.258665905716416
# 194200
# [-0.7350122]
# [1.1890423]
# training idx 1 actor true_reward at iteration 980 : -15.528479433035004
# 196200
# [-0.9000215]
# [1.8155688]
# training idx 1 actor true_reward at iteration 990 : -15.705931256041563
# 198200
# [-0.9360086]
# [2.3546245]
# training idx 1 actor true_reward at iteration 1000 : -41.07150134957037
# 200200
# [-1.2379068]
# [2.3614745]
# training idx 1 actor true_reward at iteration 1010 : -66.31785692408937
# 202200
# [-0.31046972]
# [0.07237408]
# training idx 1 actor true_reward at iteration 1020 : -7.40441196183318
# 204200
# [-0.9781166]
# [0.5082722]
# training idx 1 actor true_reward at iteration 1030 : -23.851740045425398
# 206200
# [-1.3435977]
# [1.7283021]
# training idx 1 actor true_reward at iteration 1040 : -15.234014861924043
# 208200
# [-1.4944438]
# [1.6741978]
# training idx 1 actor true_reward at iteration 1050 : -16.44836963515558
# 210200
# [-0.7929288]
# [0.3753327]
# training idx 1 actor true_reward at iteration 1060 : -7.644327731497995
# 212200
# [-1.2404628]
# [2.7170565]
# training idx 1 actor true_reward at iteration 1070 : -25.553144202822455
# 214200
